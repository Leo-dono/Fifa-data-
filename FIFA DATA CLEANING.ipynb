# %%
#import libraries 
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

#import csv and read with pandas
df = pd.read_csv('C:/Users/HP ALL IN ONE/Desktop/fifa21 raw data v2.csv',low_memory = False)
df.describe()
# Out:
#                   ID           Age          ↓OVA           POT           BOV  \
# count   18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean   226403.384794     25.194109     65.718636     71.136414     66.751726
# std     27141.054157      4.710520      6.968999      6.114635      6.747193
# min        41.000000     16.000000     47.000000     47.000000     48.000000
# 25%    210135.000000     21.000000     61.000000     67.000000     62.000000
# 50%    232418.000000     25.000000     66.000000     71.000000     67.000000
# 75%    246922.500000     29.000000     70.000000     75.000000     71.000000
# max    259216.000000     53.000000     93.000000     95.000000     93.000000
#
#           Attacking      Crossing     Finishing  Heading Accuracy  \
# count  18979.000000  18979.000000  18979.000000      18979.000000
# mean     248.938142     49.688392     45.842405         51.942726
# std       74.299428     18.131153     19.567081         17.294409
# ...

# %%
#get the number of rows and columns
df.shape
# Out:
# (18979, 77)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %%
#rename LongName 
df=df.rename(columns={'LongName':'Full Name'})
#df=df.rename(columns={'W/F':'wing_f'})

# %%
df.head(10)
# Out:
#        ID               Name                     Full Name  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
# 5  188545     R. Lewandowski            Robert Lewandowski
# 6  209331           M. Salah                 Mohamed Salah
# 7  212831            Alisson         Alisson Ramses Becker
# 8  231747          K. Mbappé                 Kylian Mbappé
# 9  192448      M. ter Stegen         Marc-André ter Stegen
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# ...

# %% [markdown]
# Describe loan date end column

# %%
#check the loan date end for missen data
df['Loan Date End'].describe()
# Out:
# count             1013
# unique              24
# top       Jun 30, 2021
# freq               770
# Name: Loan Date End, dtype: object

# %%
#drop loand date end because it has missen data
df.drop('Loan Date End',axis=1,inplace=True)

# %%
#remove the \n\n\n\n from the club names
df.Club = df.Club.str.replace('\n\n\n\n',' ')
#df['Club'].apply(lambda x:x[4:])
df.Club
# Out:
# 0                FC Barcelona
# 1                    Juventus
# 2             Atlético Madrid
# 3             Manchester City
# 4         Paris Saint-Germain
#                  ...
# 18974              Wuhan Zall
# 18975         Oldham Athletic
# 18976              Derry City
# 18977        Dalian YiFang FC
# 18978        Dalian YiFang FC
# Name: Club, Length: 18979, dtype: object

# %%
df.head()
# Out:
#        ID               Name                     Full Name  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
df[['W/F','SM','IR']].head(10)
# Out:
#    W/F  SM   IR
# 0  4 ★  4★  5 ★
# 1  4 ★  5★  5 ★
# 2  3 ★  1★  3 ★
# 3  5 ★  4★  4 ★
# 4  5 ★  5★  5 ★
# 5  4 ★  4★  4 ★
# 6  3 ★  4★  3 ★
# 7  3 ★  1★  3 ★
# 8  4 ★  5★  3 ★
# 9  4 ★  1★  3 ★

# %%
#create function to remove stars 
def delete_star(val):
    val = val.replace('★','')
    return val

# %%
#df[W/F]=df[W/F].apply(lambda val = val.str.strip('★')

# %%
#apply the functions
df.IR=df.IR.apply(delete_star)
df.SM=df.SM.apply(delete_star)

# %%
df[['W/F','SM','IR']].head(10)
# Out:
#    W/F SM  IR
# 0  4 ★  4  5
# 1  4 ★  5  5
# 2  3 ★  1  3
# 3  5 ★  4  4
# 4  5 ★  5  5
# 5  4 ★  4  4
# 6  3 ★  4  3
# 7  3 ★  1  3
# 8  4 ★  5  3
# 9  4 ★  1  3

# %%
#i renamed it because when i tried applying the function to W/F the / sign was giving problems. it was acting as a division sign
df=df.rename(columns={'W/F':'WF'})

# %%
df[['WF','SM','IR']].head(10)
# Out:
#     WF SM  IR
# 0  4 ★  4  5
# 1  4 ★  5  5
# 2  3 ★  1  3
# 3  5 ★  4  4
# 4  5 ★  5  5
# 5  4 ★  4  4
# 6  3 ★  4  3
# 7  3 ★  1  3
# 8  4 ★  5  3
# 9  4 ★  1  3

# %%
df.WF=df.WF.apply(delete_star)
df[['WF','SM','IR']].head(10)
# Out:
#    WF SM  IR
# 0  4   4  5
# 1  4   5  5
# 2  3   1  3
# 3  5   4  4
# 4  5   5  5
# 5  4   4  4
# 6  3   4  3
# 7  3   1  3
# 8  4   5  3
# 9  4   1  3

# %%
df.Contract.unique()
# Out:
# array(['2004 ~ 2021', '2018 ~ 2022', '2014 ~ 2023', '2015 ~ 2023',
#        '2017 ~ 2022', '2017 ~ 2023', '2018 ~ 2024', '2014 ~ 2022',
#        '2018 ~ 2023', '2016 ~ 2023', '2013 ~ 2023', '2011 ~ 2023',
#        '2009 ~ 2022', '2005 ~ 2021', '2011 ~ 2021', '2015 ~ 2022',
#        '2017 ~ 2024', '2010 ~ 2024', '2012 ~ 2021', '2019 ~ 2024',
#        '2015 ~ 2024', '2017 ~ 2025', '2020 ~ 2025', '2019 ~ 2023',
#        '2008 ~ 2023', '2015 ~ 2021', '2020 ~ 2022', '2012 ~ 2022',
#        '2016 ~ 2025', '2013 ~ 2022', '2011 ~ 2022', '2012 ~ 2024',
#        '2016 ~ 2021', '2012 ~ 2023', '2008 ~ 2022', '2019 ~ 2022',
#        '2017 ~ 2021', '2013 ~ 2024', '2020 ~ 2024', '2010 ~ 2022',
#        '2020 ~ 2021', '2011 ~ 2024', '2020 ~ 2023', '2014 ~ 2024',
#        '2013 ~ 2026', '2016 ~ 2022', '2010 ~ 2021', '2013 ~ 2021',
#        '2019 ~ 2025', '2018 ~ 2025', '2016 ~ 2024', '2018 ~ 2021',
#        '2009 ~ 2024', '2007 ~ 2022', 'Jun 30, 2021 On Loan',
# ...

# %%
df.head()
# Out:
#        ID               Name                     Full Name  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
#define a function categorize the contracts into 3 
def contract(x):
    if '~'in x:
        x= 'ACTIVE'
        return x
    elif 'Loan'in x:
        x= 'ON LOAN'
        return x
    elif 'Free' in x:
        x= 'FREE'
        return x

# %%
#apply the function
df.Contract = df.Contract.apply(contract)
df.Contract = df.Contract.astype('category')
df.Contract.unique
# Out:
# <bound method Series.unique of 0        ACTIVE
# 1        ACTIVE
# 2        ACTIVE
# 3        ACTIVE
# 4        ACTIVE
#           ...
# 18974    ACTIVE
# 18975    ACTIVE
# 18976    ACTIVE
# 18977    ACTIVE
# 18978    ACTIVE
# Name: Contract, Length: 18979, dtype: category
# Categories (3, object): ['ACTIVE', 'FREE', 'ON LOAN']>

# %%
#rename Contract column
df=df.rename(columns={'Contract':'Contract Status'})

# %%
df
# Out:
#            ID               Name                     Full Name  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978  252520          Zhou Xiao                     Xiao Zhou
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# ...

# %%
df.Weight.unique
# Out:
# <bound method Series.unique of 0        72kg
# 1        83kg
# 2        87kg
# 3        70kg
# 4        68kg
#          ...
# 18974    66kg
# 18975    65kg
# 18976    74kg
# 18977    69kg
# 18978    75kg
# Name: Weight, Length: 18979, dtype: object>

# %%
#define a function to remove the kg and lbs and convert all lbs to kg
def All_to_kg(x):
    if 'kg'in x:
        x = x.strip('kg')
        return x
    elif 'lbs'in x:
        x=x.strip('lbs')
        weight = round((float(x)*0.453592),2)
        return weight

# %%
#apply function
df['Weight']=df['Weight'].apply(All_to_kg)

# %%
df.Weight.unique
# Out:
# <bound method Series.unique of 0        72
# 1        83
# 2        87
# 3        70
# 4        68
#          ..
# 18974    66
# 18975    65
# 18976    74
# 18977    69
# 18978    75
# Name: Weight, Length: 18979, dtype: object>

# %%
#change weight data type to float and rename it appropriately
df['Weight']=df['Weight'].astype(float)
df=df.rename(columns={'Weight':'Weight_Kg'})
df.Weight_Kg.unique
# Out:
# <bound method Series.unique of 0        72.0
# 1        83.0
# 2        87.0
# 3        70.0
# 4        68.0
#          ...
# 18974    66.0
# 18975    65.0
# 18976    74.0
# 18977    69.0
# 18978    75.0
# Name: Weight_Kg, Length: 18979, dtype: float64>

# %%
df
# Out:
#            ID               Name                     Full Name  \
# 0      158023           L. Messi                  Lionel Messi
# 1       20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2      200389           J. Oblak                     Jan Oblak
# 3      192985       K. De Bruyne               Kevin De Bruyne
# 4      190871          Neymar Jr    Neymar da Silva Santos Jr.
# ...       ...                ...                           ...
# 18974  247223             Xia Ao                        Ao Xia
# 18975  258760           B. Hough                     Ben Hough
# 18976  252757        R. McKinley                Ronan McKinley
# 18977  243790       Wang Zhen'ao                  Zhen'ao Wang
# 18978  252520          Zhou Xiao                     Xiao Zhou
#
#                                                photoUrl  \
# 0      https://cdn.sofifa.com/players/158/023/21_60.png
# 1      https://cdn.sofifa.com/players/020/801/21_60.png
# ...

# %%
#drop name column
df.drop('Name',axis=1,inplace=True)

# %%
df.head(5)
# Out:
#        ID                     Full Name  \
# 0  158023                  Lionel Messi
# 1   20801  C. Ronaldo dos Santos Aveiro
# 2  200389                     Jan Oblak
# 3  192985               Kevin De Bruyne
# 4  190871    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# 2  http://sofifa.com/player/200389/jan-oblak/210006/    Slovenia   27    91
# 3  http://sofifa.com/player/192985/kevin-de-bruyn...     Belgium   29    91
# ...

# %%
#remove euro sign from these 3 columns
df['Wage']=df['Wage'].str.strip('€')

# %%
df['Value']=df['Value'].str.strip('€')

# %%
df['Release Clause']=df['Release Clause'].str.strip('€')

# %%
#define a function to convert M and K values to actual float values
def change_value(x):
    if 'M' in x:
        x=x.strip('M')
        value=float(x)*1000000
        return value
    elif 'K'in x:
        x=x.strip('K')
        value=float(x)*1000
        return value
    else:
        value=float(x)
        return value

# %%
#apply function
df['Wage']=df['Wage'].apply(change_value)
df['Value']=df['Value'].apply(change_value)
df['Release Clause']=df['Release Clause'].apply(change_value)

# %%
df[['Release Clause','Value','Wage']].head(10)
# Out:
#    Release Clause        Value      Wage
# 0     138400000.0  103500000.0  560000.0
# 1      75900000.0   63000000.0  220000.0
# 2     159400000.0  120000000.0  125000.0
# 3     161000000.0  129000000.0  370000.0
# 4     166500000.0  132000000.0  270000.0
# 5     132000000.0  111000000.0  240000.0
# 6     144300000.0  120500000.0  250000.0
# 7     120300000.0  102000000.0  160000.0
# 8     203100000.0  185500000.0  160000.0
# 9     147700000.0  110000000.0  260000.0

# %%
#rename Height column 
df=df.rename(columns={'Height':'Height_cm'})

# %%
df['Height_cm'].head()
# Out:
# 0    170cm
# 1    187cm
# 2    188cm
# 3    181cm
# 4    175cm
# Name: Height_cm, dtype: object

# %%
#remove cm from the height vakues
df['Height_cm']=df['Height_cm'].str.strip('cm')

# %%
df['Height_cm'].head()
# Out:
# 0    170
# 1    187
# 2    188
# 3    181
# 4    175
# Name: Height_cm, dtype: object

# %%
df.head(2)
# Out:
#        ID                     Full Name  \
# 0  158023                  Lionel Messi
# 1   20801  C. Ronaldo dos Santos Aveiro
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT           Club Contract Status   Positions Height_cm  Weight_Kg  \
# 0   93   FC Barcelona          ACTIVE  RW, ST, CF       170       72.0
# 1   92       Juventus          ACTIVE      ST, LW       187       83.0
#
#   Preferred Foot  BOV Best Position        Joined        Value      Wage  \
# 0           Left   93            RW   Jul 1, 2004  103500000.0  560000.0
# 1          Right   92            ST  Jul 10, 2018   63000000.0  220000.0
#
# ...

# %%
def attacking(x):
    x = (x/500)*100
    return x

# %%
df['Attacking']=df['Attacking'].apply(attacking)
df=df.rename(columns={'Attacking':'Attacking(%)'})

# %%
df['Attacking(%)'].head(5)
# Out:
# 0    85.8
# 1    87.4
# 2    19.0
# 3    81.4
# 4    81.6
# Name: Attacking(%), dtype: float64

# %%
df.head(2)
# Out:
#        ID                     Full Name  \
# 0  158023                  Lionel Messi
# 1   20801  C. Ronaldo dos Santos Aveiro
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT           Club Contract Status   Positions Height_cm  Weight_Kg  \
# 0   93   FC Barcelona          ACTIVE  RW, ST, CF       170       72.0
# 1   92       Juventus          ACTIVE      ST, LW       187       83.0
#
#   Preferred Foot  BOV Best Position        Joined        Value      Wage  \
# 0           Left   93            RW   Jul 1, 2004  103500000.0  560000.0
# 1          Right   92            ST  Jul 10, 2018   63000000.0  220000.0
#
# ...

# %%
#define functions to convert columns into percentages
def Movement(x):
    x = (x/500)*100
    return x

# %%
df['Movement']=df['Movement'].apply(Movement)
df=df.rename(columns={'Movement':'Movement(%)'})
df['Movement(%)'].head(5)
# Out:
# 0    90.2
# 1    86.2
# 2    61.4
# 3    79.6
# 4    90.6
# Name: Movement(%), dtype: float64

# %%
def Power(x):
    x = (x/500)*100
    return x

# %%
df['Power']=df['Power'].apply(Power)
df=df.rename(columns={'Power':'Power(%)'})
df['Power(%)'].head(5)
# Out:
# 0    77.8
# 1    88.8
# 2    53.6
# 3    81.6
# 4    71.4
# Name: Power(%), dtype: float64

# %%
df.head(2)
# Out:
#        ID                     Full Name  \
# 0  158023                  Lionel Messi
# 1   20801  C. Ronaldo dos Santos Aveiro
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT           Club Contract Status   Positions Height_cm  Weight_Kg  \
# 0   93   FC Barcelona          ACTIVE  RW, ST, CF       170       72.0
# 1   92       Juventus          ACTIVE      ST, LW       187       83.0
#
#   Preferred Foot  BOV Best Position        Joined        Value      Wage  \
# 0           Left   93            RW   Jul 1, 2004  103500000.0  560000.0
# 1          Right   92            ST  Jul 10, 2018   63000000.0  220000.0
#
# ...

# %%
def Mentality(x):
    x = (x/600)*100
    return x

# %%
df['Mentality']=df['Mentality'].apply(Mentality)
df=df.rename(columns={'Mentality':'Mentality(%)'})
df['Mentality(%)'].head(2)
# Out:
# 0    57.833333
# 1    58.833333
# Name: Mentality(%), dtype: float64

# %%
def Defending(x):
    x = (x/300)*100
    return x

# %%
df['Defending']=df['Defending'].apply(Mentality)
df=df.rename(columns={'Defending':'Defending(%)'})
df['Defending(%)'].head(2)
# Out:
# 0    15.166667
# 1    14.000000
# Name: Defending(%), dtype: float64

# %%
def Goalkeeping(x):
    x = (x/500)*100
    return x

# %%
df['Goalkeeping']=df['Goalkeeping'].apply(Mentality)
df=df.rename(columns={'Goalkeeping':'Goalkeeping(%)'})
df['Goalkeeping(%)'].head(2)
# Out:
# 0    9.000000
# 1    9.666667
# Name: Goalkeeping(%), dtype: float64

# %%
df.head(2)
# Out:
#        ID                     Full Name  \
# 0  158023                  Lionel Messi
# 1   20801  C. Ronaldo dos Santos Aveiro
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
#
#    POT           Club Contract Status   Positions Height_cm  Weight_Kg  \
# 0   93   FC Barcelona          ACTIVE  RW, ST, CF       170       72.0
# 1   92       Juventus          ACTIVE      ST, LW       187       83.0
#
#   Preferred Foot  BOV Best Position        Joined        Value      Wage  \
# 0           Left   93            RW   Jul 1, 2004  103500000.0  560000.0
# 1          Right   92            ST  Jul 10, 2018   63000000.0  220000.0
#
# ...

# %%
df.drop('photoUrl',axis=1,inplace=True)
df.drop('playerUrl',axis=1,inplace=True)
df.head(2)
# Out:
#        ID                     Full Name Nationality  Age  ↓OVA  POT  \
# 0  158023                  Lionel Messi   Argentina   33    93   93
# 1   20801  C. Ronaldo dos Santos Aveiro    Portugal   35    92   92
#
#             Club Contract Status   Positions Height_cm  Weight_Kg  \
# 0   FC Barcelona          ACTIVE  RW, ST, CF       170       72.0
# 1       Juventus          ACTIVE      ST, LW       187       83.0
#
#   Preferred Foot  BOV Best Position        Joined        Value      Wage  \
# 0           Left   93            RW   Jul 1, 2004  103500000.0  560000.0
# 1          Right   92            ST  Jul 10, 2018   63000000.0  220000.0
#
#    Release Clause  Attacking(%)  Crossing  Finishing  Heading Accuracy  \
# 0     138400000.0          85.8        85         95                70
# 1      75900000.0          87.4        84         95                90
#
#    Short Passing  Volleys  Skill  Dribbling  Curve  FK Accuracy  Long Passing  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 73 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Full Name         18979 non-null  object
#  2   Nationality       18979 non-null  object
#  3   Age               18979 non-null  int64
#  4   ↓OVA              18979 non-null  int64
#  5   POT               18979 non-null  int64
#  6   Club              18979 non-null  object
#  7   Contract Status   18979 non-null  category
#  8   Positions         18979 non-null  object
#  9   Height_cm         18979 non-null  object
#  10  Weight_Kg         18979 non-null  float64
#  11  Preferred Foot    18979 non-null  object
#  12  BOV               18979 non-null  int64
#  13  Best Position     18979 non-null  object
#  14  Joined            18979 non-null  object
#  15  Value             18979 non-null  float64
# ...

# %%
def int64_to_float64(df):
    """
    Convert all int64 columns to float64 in a Pandas DataFrame.
    
    Args:
    df (pandas.DataFrame): The DataFrame to modify.
    
    Returns:
    pandas.DataFrame: A new DataFrame with all int64 columns converted to float64.
    """
    # Find all int64 columns
    int_cols = df.select_dtypes(include=['int64']).columns
    
    # Convert int64 columns to float64
    df[int_cols] = df[int_cols].astype('float64')
    
    return df

# %%
df =int64_to_float64(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 73 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  float64
#  1   Full Name         18979 non-null  object
#  2   Nationality       18979 non-null  object
#  3   Age               18979 non-null  float64
#  4   ↓OVA              18979 non-null  float64
#  5   POT               18979 non-null  float64
#  6   Club              18979 non-null  object
#  7   Contract Status   18979 non-null  category
#  8   Positions         18979 non-null  object
#  9   Height_cm         18979 non-null  object
#  10  Weight_Kg         18979 non-null  float64
#  11  Preferred Foot    18979 non-null  object
#  12  BOV               18979 non-null  float64
#  13  Best Position     18979 non-null  object
#  14  Joined            18979 non-null  object
#  15  Value             18979 non-null  float64
# ...

# %%
df['ID']=df['ID'].astype(int)
df['ID'].head(20)
# Out:
# 0     158023
# 1      20801
# 2     200389
# 3     192985
# 4     190871
# 5     188545
# 6     209331
# 7     212831
# 8     231747
# 9     192448
# 10    203376
# 11    208722
# 12    200145
# 13    192119
# 14    167495
# 15    165153
# 16    155862
# 17    153079
# 18    202652
# 19    215914
# Name: ID, dtype: int32

# %%
df['Hits'].unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...

# %%
df.Hits = df.Hits.fillna('0')
df['Hits'].unique()
# Out:
# array(['771', '562', '150', '207', '595', '248', '246', '120', '1.6K',
#        '130', '321', '189', '175', '96', '118', '216', '212', '154',
#        '205', '202', '339', '408', '103', '332', '86', '173', '161',
#        '396', '1.1K', '433', '242', '206', '177', '1.5K', '198', '459',
#        '117', '119', '209', '84', '187', '165', '203', '65', '336', '126',
#        '313', '124', '145', '538', '182', '101', '45', '377', '99', '194',
#        '403', '414', '593', '374', '245', '3.2K', '266', '299', '309',
#        '215', '265', '211', '112', '337', '70', '159', '688', '116', '63',
#        '144', '123', '71', '224', '113', '168', '61', '89', '137', '278',
#        '75', '148', '176', '197', '264', '214', '247', '402', '440',
#        '1.7K', '2.3K', '171', '320', '657', '87', '259', '200', '255',
#        '253', '196', '60', '97', '85', '169', '256', '132', '239', '166',
#        '121', '109', '32', '46', '122', '48', '527', '199', '282', '51',
# ...

# %%
df['Hits']=df['Hits'].astype(str)
def change_value(x):
    if 'K'in x:
        x=x.strip('K')
        value=float(x)*1000
        return value
    else:
        value=x
        return value

# %%
df['Hits']=df['Hits'].apply(change_value)
df['Hits']=df['Hits'].astype(int)

# %%
df['Hits'].unique()
# Out:
# array([ 771,  562,  150,  207,  595,  248,  246,  120, 1600,  130,  321,
#         189,  175,   96,  118,  216,  212,  154,  205,  202,  339,  408,
#         103,  332,   86,  173,  161,  396, 1100,  433,  242,  206,  177,
#        1500,  198,  459,  117,  119,  209,   84,  187,  165,  203,   65,
#         336,  126,  313,  124,  145,  538,  182,  101,   45,  377,   99,
#         194,  403,  414,  593,  374,  245, 3200,  266,  299,  309,  215,
#         265,  211,  112,  337,   70,  159,  688,  116,   63,  144,  123,
#          71,  224,  113,  168,   61,   89,  137,  278,   75,  148,  176,
#         197,  264,  214,  247,  402,  440, 1700, 2300,  171,  320,  657,
#          87,  259,  200,  255,  253,  196,   60,   97,   85,  169,  256,
#         132,  239,  166,  121,  109,   32,   46,  122,   48,  527,  199,
#         282,   51, 1900,  642,  155,  323,  288,  497,  509,   79,   49,
#         270,  511,   80,  128,  115,  156,  204,  143,  140,  152,  220,
# ...

# %%
for names in df.columns:
    values = df[names].unique()
    print(f'{names}-{values}.\n')
# Out:
# ID-[158023  20801 200389 ... 252757 243790 252520].
#
# Full Name-['Lionel Messi' 'C. Ronaldo dos Santos Aveiro' 'Jan Oblak' ...
#  'Ronan McKinley' "Zhen'ao Wang" 'Xiao Zhou'].
#
# Nationality-['Argentina' 'Portugal' 'Slovenia' 'Belgium' 'Brazil' 'Poland' 'Egypt'
#  'France' 'Germany' 'Netherlands' 'Senegal' 'Spain' 'England' 'Scotland'
#  'Korea Republic' 'Costa Rica' 'Italy' 'Gabon' 'Croatia' 'Uruguay'
#  'Switzerland' 'Serbia' 'Slovakia' 'Morocco' 'Algeria' 'Denmark' 'Hungary'
#  'Bosnia Herzegovina' 'Nigeria' 'Cameroon' 'Norway' 'Ghana' 'Mexico'
#  'Austria' 'Albania' 'Colombia' 'Chile' 'Ivory Coast' 'Greece' 'Finland'
#  'Wales' 'Sweden' 'Togo' 'Czech Republic' 'Russia' 'Venezuela' 'Canada'
#  'United States' 'Guinea' 'Montenegro' 'Israel' 'Republic of Ireland'
#  'Ukraine' 'Turkey' 'Ecuador' 'Jamaica' 'DR Congo' 'Australia' 'China PR'
#  'Armenia' 'Northern Ireland' 'North Macedonia' 'Kosovo' 'Mali' 'Peru'
# ...

# %%
#forgot height
df['Height_cm'].unique()
# Out:
# array(['170', '187', '188', '181', '175', '184', '191', '178', '193',
#        '185', '199', '173', '168', '176', '177', '183', '180', '189',
#        '179', '195', '172', '182', '186', '192', '165', '194', '167',
#        '196', '163', '190', '174', '169', '171', '197', '200', '166',
#        '6\'2"', '164', '198', '6\'3"', '6\'5"', '5\'11"', '6\'4"',
#        '6\'1"', '6\'0"', '5\'10"', '5\'9"', '5\'6"', '5\'7"', '5\'4"',
#        '201', '158', '162', '161', '160', '203', '157', '156', '202',
#        '159', '206', '155'], dtype=object)

# %%
def convert_height_to_cm(x):
    if "'" in x:
        feet, inches = x.split("'")       
        feet = float(feet.replace("'",'') )
        inches = float(inches.replace('"','') )                       
        cm = float(feet) * 30.48 + float(inches) * 2.54
        return cm
    else :
        return float(x)

# %%
df['Height_cm']=df['Height_cm'].apply(convert_height_to_cm)
df['Height_cm'].unique()
# Out:
# array([170.  , 187.  , 188.  , 181.  , 175.  , 184.  , 191.  , 178.  ,
#        193.  , 185.  , 199.  , 173.  , 168.  , 176.  , 177.  , 183.  ,
#        180.  , 189.  , 179.  , 195.  , 172.  , 182.  , 186.  , 192.  ,
#        165.  , 194.  , 167.  , 196.  , 163.  , 190.  , 174.  , 169.  ,
#        171.  , 197.  , 200.  , 166.  , 187.96, 164.  , 198.  , 190.5 ,
#        195.58, 180.34, 193.04, 185.42, 182.88, 177.8 , 175.26, 167.64,
#        170.18, 162.56, 201.  , 158.  , 162.  , 161.  , 160.  , 203.  ,
#        157.  , 156.  , 202.  , 159.  , 206.  , 155.  ])

# %%
for names in df.columns:
    values = df[names].unique()
    print(f'{names}-{values}.\n')
# Out:
# ID-[158023  20801 200389 ... 252757 243790 252520].
#
# Full Name-['Lionel Messi' 'C. Ronaldo dos Santos Aveiro' 'Jan Oblak' ...
#  'Ronan McKinley' "Zhen'ao Wang" 'Xiao Zhou'].
#
# Nationality-['Argentina' 'Portugal' 'Slovenia' 'Belgium' 'Brazil' 'Poland' 'Egypt'
#  'France' 'Germany' 'Netherlands' 'Senegal' 'Spain' 'England' 'Scotland'
#  'Korea Republic' 'Costa Rica' 'Italy' 'Gabon' 'Croatia' 'Uruguay'
#  'Switzerland' 'Serbia' 'Slovakia' 'Morocco' 'Algeria' 'Denmark' 'Hungary'
#  'Bosnia Herzegovina' 'Nigeria' 'Cameroon' 'Norway' 'Ghana' 'Mexico'
#  'Austria' 'Albania' 'Colombia' 'Chile' 'Ivory Coast' 'Greece' 'Finland'
#  'Wales' 'Sweden' 'Togo' 'Czech Republic' 'Russia' 'Venezuela' 'Canada'
#  'United States' 'Guinea' 'Montenegro' 'Israel' 'Republic of Ireland'
#  'Ukraine' 'Turkey' 'Ecuador' 'Jamaica' 'DR Congo' 'Australia' 'China PR'
#  'Armenia' 'Northern Ireland' 'North Macedonia' 'Kosovo' 'Mali' 'Peru'
# ...

# %%
df.to_csv('my_cleaned_fifa_data.csv', index=False)
